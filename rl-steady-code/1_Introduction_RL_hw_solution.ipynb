# %% [markdown]
# # Q-러닝 Homework

# %% [markdown]
# # Q 러닝을 이용한 게임 실습

# %%
! pip install gym==0.15.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.6 MB/s eta 0:00:00
# ...
#   Created wheel for gym: filename=gym-0.15.3-py3-none-any.whl size=1644931 sha256=6f034afe123c5a11179607e3b62798124b8d41577c29386b61668ca3c6a4acba
#   Stored in directory: /root/.cache/pip/wheels/dc/4c/1c/25048a3f2e8540c60bbba0c25d8400f959205db1048431873a
# Successfully built gym
# ...
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from gym.envs.registration import register

# %%
def simulate_policy(env, Q):
    state = env.reset()
    done = False

    while not done:
        action = np.argmax(Q[state, :]) #행동은 Q-table에서 가장 큰 Q값을 가지는 행동을 선택합니다.
        new_state, _, done, _ = env.step(action)  #환경에서 action을 취했을 때 다음 상태, 보상, 종료 여부 등의 정보를 반환합니다.
        env.render()                              #현재 상태를 가시적으로 보여줍니다.
        state = new_state                         #상태를 변경하고, 에피소드가 끝날 때 까지 반복합니다.

# %% [markdown]
# 이번엔 openai gym의 환경중 하나인 Cliffwalking을 진행해보겠습니다.
# <br>

# %% [markdown]
# ![cliff_walking.gif](data:image/gif;base64,...)

# %% [markdown]
# #HW1. e-greedy 방법으로 Q-learning을 작성합니다.

# %% [markdown]
# # Q-learning의 식은 다음과 같습니다.
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # seaborn을 사용하여 히트맵을 그립니다
from matplotlib.colors import ListedColormap
import gym

# CliffWalking 환경 생성
env = gym.make('CliffWalking-v0')

# Q table을 observation과 action space의 크기로 초기화합니다.
Q =

#하이퍼파라미터는 아래와 같이 사용하되, 변경해도 문제 없습니다.
discount_factor = 0.99
num_episodes = 2000
alpha = 0.9

total_reward = []
total_reward_sum = []
for i in range(num_episodes):

    # 가장 먼저, 환경을 초기화합니다.
    state =

    # reward 의 합을 0으로 초기화합니다.
    reward_sum =

    # 에피소드가 끝났음을 알리는 done_mask를 False로 초기화합니다.
    done =

    #학습이 진행될수록 점점 줄어드는 epsilon 값을 정의합니다.
    #이 때, epsilon 값은 50 episode마다 감소하도록 설정합니다.
    e =

    while not done:
        #epsilon의 확률로 무작위 행동을 선택합니다.
        if np.random.rand(1) < e:
            action =
        #이외의 경우엔 Q값을 따라가도록 행동을 선택택합니다.
        else:
            action =

        #선택된 행동을 환경에서 실행합니다.
        new_state, reward, done, _ =

        #Q 값을 업데이트 합니다.(위에 있는 식과 동일하게 작성하면 됩니다)
        Q[state, action] = Q[state, action] +

        reward_sum += reward
        state = new_state

    total_reward.append(reward_sum)
    total_reward_sum.append(sum(total_reward)/(i+1))

print("Final Q-Table Values")
print(Q)
plt.figure()
plt.plot(total_reward_sum)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.show()

simulate_policy(env, Q)

print("Simulation complete.")

env.close()

# %% [markdown]
# #HW1. solution

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # seaborn을 사용하여 히트맵을 그립니다
from matplotlib.colors import ListedColormap
import gym

# CliffWalking 환경 생성
env = gym.make('CliffWalking-v0')
Q = np.zeros([env.observation_space.n, env.action_space.n])

discount_factor = 0.99
num_episodes = 2000
alpha = 0.9

total_reward = []
total_reward_sum = []
for i in range(num_episodes):

    state = env.reset()
    reward_sum = 0
    done = False

    #학습이 진행될수록 점점 줄어드는 epsilon 값을 정의합니다.
    e = 1. / ((i // 50) + 1)

    while not done:
        #epsilon의 확률로 무작위 행동을 선택합니다.
        if np.random.rand(1) < e:
            action = env.action_space.sample()
        #이외의 경우엔 Q값을 따라가도록 행동을 선택택합니다.
        else:
            action = np.argmax(Q[state, :])
        new_state, reward, done, _ = env.step(action)

        Q[state, action] = Qt[state, acion] + alpha * (reward + discount_factor * np.max(Q[new_state]) - Q[state, action])

        reward_sum += reward
        state = new_state

    total_reward.append(reward_sum)
    total_reward_sum.append(sum(total_reward)/(i+1))

print("Final Q-Table Values")
print(Q)
plt.figure()
plt.plot(total_reward_sum)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.show()

simulate_policy(env, Q)

print("Simulation complete.")

env.close()
# Out:
# Final Q-Table Values
# [[ -13.99416454  -13.12541872  -13.12541872  -13.99416454]
#  [ -13.12541872  -12.2478977   -12.2478977   -13.99416454]
#  [ -12.2478977   -11.36151283  -11.36151283  -13.12541872]
#  [ -11.36151283  -10.46617457  -10.46617457  -12.2478977 ]
#  [ -10.46617457   -9.5617925    -9.5617925   -11.36151283]
#  [  -9.5617925    -8.64827525   -8.64827525  -10.46617457]
#  [  -8.64827525   -7.72553056   -7.72553056   -9.5617925 ]
#  [  -7.72553056   -6.79346521   -6.79346521   -8.64827525]
#  [  -6.79346521   -5.85198506   -5.85198506   -7.72553056]
#  [  -5.85198506   -4.90099501   -4.90099501   -6.79346521]
#  [  -4.90099501   -3.940399     -3.940399     -5.85198506]
#  [  -3.940399     -3.940399     -2.9701       -4.90099501]
#  [ -13.99416454  -12.2478977   -12.2478977   -13.12541872]
#  [ -13.12541872  -11.36151283  -11.36151283  -13.12541872]
#  [ -12.2478977   -10.46617457  -10.46617457  -12.2478977 ]
#  [ -11.36151283   -9.5617925    -9.5617925   -11.36151283]
# ...

# %% [markdown]
# #HW2. random noise의 SARSA를 진행해봅니다.

# %% [markdown]
# <br> SARSA는 다음과 같은 식을 따르도록 학습합니다.
# ![image.png](data:image/png;base64,...)

# %%
# CliffWalking 환경 생성
env = gym.make('CliffWalking-v0')

# Q table을 observation과 action space의 크기로 초기화합니다.
Q =

#하이퍼파라미터는 아래와 같이 사용하되, 변경해도 문제 없습니다.
discount_factor = 0.99
num_episodes = 2000
alpha = 0.9

total_reward = []
total_reward_sum = []
for i in range(num_episodes):

    # 가장 먼저, 환경을 초기화합니다.
    state =

    # reward 의 합을 0으로 초기화합니다.
    reward_sum =

    # 에피소드가 끝났음을 알리는 done_mask를 False로 초기화합니다.
    done =

    # 랜덤 노이즈를 작성합니다. 작성할 부분은 에피소드마다 노이즈가 감소하도록 만드는 부분입니다.
    # 처음엔 1의 값에서, 에피소드 10마다 값이 점차 줄어들도록 작성해줍니다.
    decay_ratio =

    random_noise = np.random.randn(1, env.action_space.n) * decay_ratio

    action = np.argmax(Q[state, :] + random_noise)

    while not done:
        new_state, reward, done, _ = env.step(action)

        #Q값에 랜덤 노이즈를 추가한 값들 중, 가장 큰 값을 선택하도록 작성합니다.
        new_action =

        #SARSA 업데이트 방법으로 Q 테이블 업데이트 코드를 작성합니다.
        Q[state, action] = Q[state, action] +

        reward_sum += reward
        state = new_state
        action = new_action

    total_reward.append(reward_sum)
    total_reward_sum.append(sum(total_reward)/(i+1))

print("Final Q-Table Values")
print(Q)
plt.figure()
plt.plot(total_reward_sum)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.show()

simulate_policy(env, Q)

print("Simulation complete.")
env.close()

# %% [markdown]
# #HW2. solution

# %%
# CliffWalking 환경 생성
env = gym.make('CliffWalking-v0')

# Q table을 observation과 action space의 크기로 초기화합니다.
Q = np.zeros([env.observation_space.n, env.action_space.n])

discount_factor = 0.99
num_episodes = 2000
alpha = 0.9

total_reward = []
total_reward_sum = []
for i in range(num_episodes):

    state = env.reset()
    reward_sum = 0
    done = False

    # 랜덤 노이즈를 작성합니다. 작성할 부분은 에피소드마다 노이즈가 감소하도록 만드는 부분입니다.
    # 처음엔 1의 값에서, 에피소드 10마다 값이 점차 줄어들도록 작성해줍니다.
    decay_ratio = 1/ ((i // 10) + 1)

    random_noise = np.random.randn(1, env.action_space.n) * decay_ratio

    action = np.argmax(Q[state, :] + random_noise)

    while not done:
        new_state, reward, done, _ = env.step(action)
        new_action = np.argmax(Q[new_state, :] + random_noise)

        #SARSA 업데이트 방법으로 Q 테이블 업데이트 코드를 작성합니다.
        Q[state, action] = Q[state, action] + alpha * (reward + discount_factor * Q[new_state, new_action] - Q[state, action])
        reward_sum += reward
        state = new_state
        action = new_action
    total_reward.append(reward_sum)
    total_reward_sum.append(sum(total_reward)/(i+1))

print("Final Q-Table Values")
print(Q)
plt.figure()
plt.plot(total_reward_sum)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.show()

simulate_policy(env, Q)

print("Simulation complete.")
env.close()
# Out:
# Final Q-Table Values
# [[-25.9359767  -21.95547824 -22.01487641 -24.39020911]
#  [-24.27862709 -20.78984653 -23.56198528 -22.47799617]
#  [-21.15973366 -15.28817904 -20.64654033 -20.89017328]
#  [-19.36215547 -14.53114251 -19.10331846 -19.88655842]
#  [-18.69945979 -13.88996522 -18.97831271 -16.72817263]
#  [-14.46574493 -13.8248963  -14.09484853 -15.53828711]
#  [-11.93813414 -10.20248488 -13.1395539  -14.86082908]
#  [-10.09789642 -10.04621803 -10.6414355  -12.60061197]
#  [ -9.15138325  -8.25703025  -7.33111046 -10.05798105]
#  [ -8.24205597  -7.16170557  -7.87276996  -8.42126754]
#  [ -7.50815812  -4.4896805   -7.25062576  -6.22394546]
#  [ -4.58714008  -1.9559911   -4.3544234   -6.70061017]
#  [-25.58048684 -21.45114472 -24.79373902 -23.81066377]
#  [-23.81932338 -20.00275257 -23.97908531 -21.4995268 ]
#  [-17.89356734 -17.66385003 -21.21483369 -21.57676049]
#  [-17.05183742 -16.59966833 -18.3580417  -19.39501697]
#  [-15.56509331 -14.71455462 -18.06773558 -19.27613129]
# ...

# %%
import os
import pandas as pd
from pandas import DataFrame

data = np.mean(total_reward[-10:])
np.save('result.npy', data)
# data_df = DataFrame(data, index=['cartpole'])
# data_df.to_csv("result_csv", index=False)
